# %% [markdown]
# # 04 — Avaliação e Teste dos Modelos
#
# Neste notebook avaliamos o desempenho dos modelos treinados:
# - Cálculo de métricas de avaliação
# - Visualização de resultados (matrizes de confusão, curvas ROC, etc.)
# - Comparação entre modelos
# - Conclusões finais

# %%
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import sys
sys.path.append('../src')
from evaluate import evaluate_classifier, evaluate_regressor

# Carregar modelo guardado
# model = joblib.load('../models/random_forest.pkl')

# Carregar dados de teste
# df = pd.read_csv('../data/processed/dados_processados.csv')
# X_test = ...
# y_test = ...

# Avaliar modelo
# resultados = evaluate_classifier(model, X_test, y_test)
# print(resultados['accuracy'])
# print(resultados['classification_report'])
