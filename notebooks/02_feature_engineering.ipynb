# %% [markdown]
# # 02 — Feature Engineering
#
# Neste notebook realizamos a preparação e transformação das variáveis:
# - Tratamento de valores em falta
# - Codificação de variáveis categóricas
# - Criação de novas variáveis (se aplicável)
# - Normalização/standardização
# - Divisão em conjuntos de treino e teste

# %%
import pandas as pd
import sys
sys.path.append('../src')
from preprocessing import remove_duplicates, fill_missing_values

# Carregar dados brutos
# df = pd.read_csv('../data/raw/[NOME_DO_FICHEIRO].csv')

# Pré-processamento
# df = remove_duplicates(df)
# df = fill_missing_values(df, strategy='mean')

# Guardar dados processados
# df.to_csv('../data/processed/dados_processados.csv', index=False)
