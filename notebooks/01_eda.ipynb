# %% [markdown]
# # 01 — Análise Exploratória de Dados (EDA)
#
# Neste notebook realizamos uma análise exploratória dos dados brutos.
# Inclui estatísticas descritivas, visualização de distribuições e identificação de padrões e anomalias.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../src')
from data_loading import load_raw_data

# Carregar dados
# df = load_raw_data('../data/raw/[NOME_DO_FICHEIRO].csv')
# df.head()
